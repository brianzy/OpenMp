# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("time.csv",header=None)
df=pd.DataFrame(np.insert(df.values, 0, values=0.424380, axis=0))
df
# Out:
#            0
# 0   0.424380
# 1   0.247890
# 2   0.126179
# 3   0.084472
# 4   0.064594
# 5   0.053213
# 6   0.045996
# 7   0.039923
# 8   0.038000
# 9   0.035858
# 10  0.036446
# 11  0.035516
# 12  0.036306
# 13  0.036411
# 14  0.037322
# 15  0.036572
# 16  0.037319
# 17  0.035271
# 18  0.037196
# 19  0.036572
# 20  0.036191
# 21  0.036774
# 22  0.035147
# 23  0.036567
# 24  0.037113
# 25  0.036680
# 26  0.036020
# 27  0.036492
# 28  0.036121
# 29  0.037504
# 30  0.036223
# 31  0.036420
# 32  0.036320

# %%
ax=sns.lineplot(x=df.index,y=df[0])
ax.set(xlabel='Number of CPU', ylabel='Time(second)')
ax.set_title("OpenMp package parallel computing improvement")
plt.savefig('time.png')

plt.show()
